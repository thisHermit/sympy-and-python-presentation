# %% [markdown]
# # Python From Scratch
#
# ### by- Code Club, CSEA

# %% [markdown]
# ## About Me
#
# * 3 years Python
# * Cloned the popular game Chain Reaction in Python from scratch.

# %% [markdown]
# ## Goals
# * Read Python
# * Understand the boring but important details of Python.
# * Convert thoughts into Python code

# %% [markdown]
# ## Two Magic Words To Remember
#
# * Thank you
# * Sorry
#
# ... Not _exactly_...
#
# They are-
# * dir
# * help
#
# Right now, don't fuss about their meaning. Just Remember their meaning.

# %% [markdown]
# ![59a22ec9b8d76288181a01ec4a9eaaed2efbc5c0a302988914f716a891ee9b6d.jpg](attachment:59a22ec9b8d76288181a01ec4a9eaaed2efbc5c0a302988914f716a891ee9b6d.jpg)

# %% [markdown]
# Can anyone guess what the following line means?
#
# print("Hello World")

# %%
print("Hello World")

# %% [markdown]
# ## *Problem #1*:
# Print your name on the python interpreter

# %% [markdown]
# ### But what is the REPL?
#
# REPL stands for Read, Eval, Print, Loop
#
# So, these things happen when I execute this code:
# * the python interpreter reads the code i wrote
# * evaluates the result of the line of code
# * prints the result
# * again starts waiting for input

# %% [markdown]
# ## Variables

# %%
a = 4
b = 5.6
c = "Hello"
d = "4"
e = True
print(a)
print(id(a))
# Out:
# 4
# 10964992

# %% [markdown]
# ## Rules to follow when naming-
#
# Names should-
# * have lowercase letters
# * have underscore between words
# * not start with numbers

# %% [markdown]
# ## Basic Mathematical Operations
#
# * +
# * -
# * *
# * /
# * \**
# * %

# %%
a = 2
b = 2
print(a + b)

# %%
# Circumference of a circle
PI = 3.14
r = 0.5
circumference = 2 * PI * r
print(circumference)

# %%
# Perimeter of a rectangle
a = 4
b = 2
perimeter = ?
print(perimeter)

# %% [markdown]
# ## *Problem #2*:
# Calculate the area of a triangle, square, rhombus, and any other shape you can think of!

# %% [markdown]
# ## Taking input
#
# Just use input()

# %%
name = input()
print(name + " is the king of the ring.")
# Out:
# john cena
# john cena is the king of the ring.

# %%
num1 = input()
num1 = num1 * 2
print(num1)
# Out:
# 5
# 55

# %% [markdown]
# ![cf4e401a50beee2f4c549e005e58de5c.png](attachment:cf4e401a50beee2f4c549e005e58de5c.png)

# %%
# Let's print He said "I'm sorry"
print("He said "I'm sorry"")

# %% [markdown]
# ### Remember dir?
#
# Lists attributes and methods

# %%
dir("string")
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
# lets try the upper function
print("string".upper())

# %%
print("String".lower())
# Out:
# string

# %% [markdown]
# ## *Problem #3*:
# Correct this sentence by using the capitalise function.
#
# s = "this sentence does not follow proper grammar."

# %%
print("hello" 2 times)
# Out:
#   File "<ipython-input-5-7b30d7942168>", line 1
#     print("hello" 2 times)
#                   ^
# SyntaxError: invalid syntax

# %%
print("hello" * 2)
# Out:
# hellohello

# %% [markdown]
# ## Sequences
#
# * lists
# * tuples
# * sets

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
fruits = []
fruits.append("banana")
fruits.append("banana")
fruits.append("banana")
print(fruits)

# %%
shopping_list = ["cheese", "butter", "cream", "tic tac"]
shopping_list.remove("cheese")
print(shopping_list)
shopping_list.append("kit kat")
print(shopping_list)
# Out:
# ['butter', 'cream', 'tic tac']
# ['butter', 'cream', 'tic tac', 'kit kat']

# %% [markdown]
# ## If you ever forget the use of append

# %%
help(list.append)

# %% [markdown]
# ## List comprehension

# %%
n = 10
first_n_squares = [i * i for i in range(n)]
print(first_n_squares)

# %% [markdown]
# Links to read:
#
# * https://www.paypal-engineering.com/2014/12/10/10-myths-of-enterprise-python/"
# * https://docs.python.org/3/
